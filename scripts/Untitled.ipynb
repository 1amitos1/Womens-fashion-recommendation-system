# %% [markdown]
# #shop user data

# %%
import pandas as pd
path =r'E:\FINAL_PROJECT_DATA\FashioNet\MAIN_SYSTEM\__data_for_simulation.csv'
df = pd.read_csv(path, delimiter=",")
df.head(30)
# Out:
#     Unnamed: 0 UserID  Age  Clothing ID  \
# 0         9556      D   28          206
# 1         1065      B   42          103
# 2        10419      D   28          221
# 3         9113      D   28          210
# 4         8978      E   25          209
# 5          782      B   42          101
# 6         4523      A   32          115
# 7         9345      E   25          220
# 8         2624      C   36          109
# 9         7308      A   32          417
# 10        8327      D   28          208
# 11        1728      D   28          119
# 12        8394      B   42          216
# 13        6629      B   42          308
# 14        3106      B   42          107
# 15         225      A   32          117
# 16        2113      D   28          116
# 17        6719      D   28          406
# 18        9626      D   28          223
# 19        1556      B   42          101
# 20        6532      B   42          305
# 21        5571      C   36          102
# 22        4113      D   28          115
# 23        4312      B   42          109
# 24         291      C   36          110
# 25        2357      B   42          101
# 26        7901      A   32          220
# 27        5485      E   25          108
# 28         852      C   36          109
# 29        6576      B   42          320
#
#                                              Pic_path  Rating  \
# 0   C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 1   C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 2   C:\Users\amit hayoun\Desktop\reant_anyway_data...       1
# 3   C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 4   C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 5   C:\Users\amit hayoun\Desktop\reant_anyway_data...       2
# 6   C:\Users\amit hayoun\Desktop\reant_anyway_data...       3
# 7   C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 8   C:\Users\amit hayoun\Desktop\reant_anyway_data...       1
# 9   C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 10  C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 11  C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 12  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 13  C:\Users\amit hayoun\Desktop\reant_anyway_data...       3
# 14  C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 15  C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 16  C:\Users\amit hayoun\Desktop\reant_anyway_data...       3
# 17  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 18                                                NaN       5
# 19  C:\Users\amit hayoun\Desktop\reant_anyway_data...       3
# 20  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 21  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 22  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 23  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 24  C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 25  C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 26  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 27  C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 28  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 29                                                NaN       5
#
#     Recommended IND  Positive Feedback Count Class Name
# 0                 1                        1    Blouses
# 1                 1                        3    Dresses
# 2                 0                        3    Blouses
# 3                 1                       11    Blouses
# 4                 1                        1    Blouses
# 5                 0                        1    Dresses
# 6                 0                        0    Dresses
# 7                 1                        0    Blouses
# 8                 0                        2    Dresses
# 9                 1                        0     Skirts
# 10                1                        0    Blouses
# 11                1                        6    Dresses
# 12                1                        3    Blouses
# 13                1                       13     Shorts
# 14                1                        4    Dresses
# 15                1                        0    Dresses
# 16                1                        3    Dresses
# 17                1                        5     Skirts
# 18                1                        2    Blouses
# 19                1                        3    Dresses
# 20                0                        0     Shorts
# 21                1                        0    Dresses
# 22                1                        0    Dresses
# 23                1                        0    Dresses
# 24                1                        0    Dresses
# 25                1                        1    Dresses
# 26                1                        3    Blouses
# 27                1                        0    Dresses
# 28                1                        0    Dresses
# 29                1                        4     Shorts

# %% [markdown]
# #user data

# %%
user_id = 'A'
data = df.loc[df["UserID"] == user_id]
data.head(5)
# Out:
#     Unnamed: 0 UserID  Age  Clothing ID  \
# 6         4523      A   32          115
# 9         7308      A   32          417
# 15         225      A   32          117
# 26        7901      A   32          220
# 33        4700      A   32          116
#
#                                              Pic_path  Rating  \
# 6   C:\Users\amit hayoun\Desktop\reant_anyway_data...       3
# 9   C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 15  C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
# 26  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 33  C:\Users\amit hayoun\Desktop\reant_anyway_data...       4
#
#     Recommended IND  Positive Feedback Count Class Name
# 6                 0                        0    Dresses
# 9                 1                        0     Skirts
# 15                1                        0    Dresses
# 26                1                        3    Blouses
# 33                0                       51    Dresses

# %% [markdown]
# #show user most faveroite items by category

# %%
category = "Dresses"
data = data.loc[data["Class Name"] == category]
data = data.sort_values(by=['Rating'],ascending=False)
data.head(5)
# Out:
#      Unnamed: 0 UserID  Age  Clothing ID  \
# 149        4337      A   32          112
# 100        2423      A   32          113
# 177        2109      A   32          103
# 166         923      A   32          112
# 155        1454      A   32          112
#
#                                               Pic_path  Rating  \
# 149  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 100  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 177  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 166  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
# 155  C:\Users\amit hayoun\Desktop\reant_anyway_data...       5
#
#      Recommended IND  Positive Feedback Count Class Name
# 149                1                        1    Dresses
# 100                1                        0    Dresses
# 177                1                       31    Dresses
# 166                1                        1    Dresses
# 155                1                        3    Dresses

# %%
import os
import cv2
import numpy as np
import random
import pandas as pd
import random
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
import numpy as np

item_1 = data.iloc[0]['Pic_path']
item_2 = data.iloc[1]['Pic_path']   
item_3 = data.iloc[2]['Pic_path']
print(item_1)
print(item_2)
print(item_3)

im1 = cv2.imread(item_1)
imS1 = cv2.resize(im1, (224, 224))
cv2.imshow('user item', imS1)

# im2 = cv2.imread(item_2)
# imS2 = cv2.resize(im2, (224, 224))

# im3 = cv2.imread(item_3)
# imS3 = cv2.resize(im3, (224, 224))

# im4 = cv2.imread(item_path_dict.get(l[3]))
# imS4 = cv2.resize(im4, (224, 224))
# #numpy_horizontal_concat = np.concatenate((imS1, imS2,imS3,imS4), axis=1)
# numpy_horizontal_concat = np.concatenate((imS2, imS3, imS4), axis=1)
# cv2.imshow('Numpy Horizontal Concat', numpy_horizontal_concat)

cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-a8ada75e0b37> in <module>
#       1 import os
# ----> 2 import cv2
#       3 import numpy as np
#       4 import random
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'cv2'
